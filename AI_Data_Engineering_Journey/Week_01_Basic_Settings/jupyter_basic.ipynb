# %% [markdown]
# Hands on

# %% [markdown]
# ## Useful shortcuts
# ### ESC to enter the command mode
#
# | Keys | Explanation |
# |---|---|
# | Shift + Enter | Move to the next cell after executing the current cell |
# | Ctrl + Enter | Execute the current cell |
# | Alt + Enter | Add a cell after excuting the current cell |
# | ESC | Command Mode |
# | Enter | Edit Mode |
# | A | Add a cell above |
# | B | Add a cell below |
# | M | Change the cell to Markdown Cell |
# | Y | Change the cell to Code Cell |
# | DD | Delete a cell |
# | Z | Undo deleted cells |

# %% [markdown]
# # Main Title (#)
# ## Section Title (##)
# ### Subsection Title (###)

# %% [markdown]
# ### list
# - Load dataset
# - Check missing values
# - Train model
# - Evaluate model

# %% [markdown]
# **important** <- bold

# %% [markdown]
# ### Table
# | Model | Accuracy |
# |---|---|
# | Logistic Regression | 0.82 |
# | Decision Tree | 0.75 |

# %%
x = 10
y = 20
x + y
# Out:
# 30

# %% [markdown]
# # Jupyter Notebook Practice
#
# ## Goal
# Understand how to use Jupyter Notebook for Python and data analysis practice.

# %%
name = "Byungkyu"
goal = "Success"

print(name)
print(goal)
# Out:
# Byungkyu
# Success

# %%
x = 10

# %%
x = x + 5

# %%
x
# Out:
# 20

# %% [markdown]
# ## Summary
#
# Today, I practiced the basic workflow of Jupyter Notebook.
# I learned how to use code cells and markdown cells, how the kernel stores variables, and why execution order matters. This notebook helped me understand how Jupyter Notebook can be used as a tool for the future.
